# %%
import os
import pandas as pd
import pickle as pkl

model_path = r"D:\ML_LEARNING\ML_PROJECTS\Indian_Railways_Failure_Prediction\artifacts\data_preprocessing.pkl"

with open(model_path,'rb') as f:
    model = pkl.load(f)

model.get_feature_names_out()
# Out:
# d:\ML_LEARNING\LLM_LEARNING\Updated_Langchain\.venv\lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator KNNImputer from version 1.9.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# d:\ML_LEARNING\LLM_LEARNING\Updated_Langchain\.venv\lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.9.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
import pandas as pd
df = pd.read_csv(r'D:\ML_LEARNING\ML_PROJECTS\Indian_Railways_Failure_Prediction\artifacts\train_dataset.csv')

# %%
df.head()
# Out:
#    train_id                 region   season train_type  train_age_years  \
# 0     76514        Central Railway   Winter  Passenger                9
# 1     60407       Southern Railway   Summer    Express               28
# 2     27323  South Central Railway  Monsoon      Metro               13
# 3     53700       Southern Railway   Summer    Freight                1
# 4     65413        Eastern Railway   Summer  Passenger                2
#
#    average_speed_kmph  distance_travelled_km  ambient_temperature_c  \
# 0           62.393712                  67123                   22.8
# 1          107.434499                 287297                   41.4
# 2           46.446730                 441985                   25.6
# 3           73.082896                  24435                   45.5
# 4           67.962021                 145661                   38.3
#
#    humidity_percent  rainfall_mm  ...  brake_pressure_psi  battery_voltage  \
# ...

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %%
df.head()
# Out:
#    train_id                 region   season train_type  train_age_years  \
# 0     76514        Central Railway   Winter  Passenger                9
# 1     60407       Southern Railway   Summer    Express               28
# 2     27323  South Central Railway  Monsoon      Metro               13
# 3     53700       Southern Railway   Summer    Freight                1
# 4     65413        Eastern Railway   Summer  Passenger                2
#
#    average_speed_kmph  distance_travelled_km  ambient_temperature_c  \
# 0           62.393712                  67123                   22.8
# 1          107.434499                 287297                   41.4
# 2           46.446730                 441985                   25.6
# 3           73.082896                  24435                   45.5
# 4           67.962021                 145661                   38.3
#
#    humidity_percent  rainfall_mm  wheel_wear_percent  track_vibration_level  \
# ...
